# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mymoviedb.csv", lineterminator='\n')
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9822   1973-10-15                              Badlands
# 9823   2020-10-01                      Violent Delights
# 9824   2016-05-06                          The Offering
# 9825   2021-03-31  The United States vs. Billie Holiday
# 9826   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df['Genre'].describe()
# Out:
# count      9827
# unique     2337
# top       Drama
# freq        466
# Name: Genre, dtype: object

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9827.000000   9827.000000
# mean     40.326088   1392.805536      6.439534
# std     108.873998   2611.206907      1.129759
# min      13.354000      0.000000      0.000000
# 25%      16.128500    146.000000      5.900000
# 50%      21.199000    444.000000      6.500000
# 75%      35.191500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'])
df['Release_Date'] = df['Release_Date'].dt.year

# %%
df
# Out:
#       Release_Date                                 Title  \
# 0             2021               Spider-Man: No Way Home
# 1             2022                            The Batman
# 2             2022                               No Exit
# 3             2021                               Encanto
# 4             2021                        The King's Man
# ...            ...                                   ...
# 9822          1973                              Badlands
# 9823          2020                      Violent Delights
# 9824          2016                          The Offering
# 9825          2021  The United States vs. Billie Holiday
# 9826          1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
cols=['Overview','Original_Language','Poster_Url']
df.drop(cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# 3           7.7  Animation, Comedy, Family, Fantasy
# 4           7.0    Action, Adventure, Thriller, War

# %%
df.describe()
# Out:
#        Release_Date   Popularity    Vote_Count  Vote_Average
# count   9827.000000  9827.000000   9827.000000   9827.000000
# mean    2006.203623    40.326088   1392.805536      6.439534
# std       15.685554   108.873998   2611.206907      1.129759
# min     1902.000000    13.354000      0.000000      0.000000
# 25%     2000.000000    16.128500    146.000000      5.900000
# 50%     2011.000000    21.199000    444.000000      6.500000
# 75%     2017.000000    35.191500   1376.000000      7.100000
# max     2024.000000  5083.954000  31077.000000     10.000000

# %%
def popularity(df,cols,labels):

    edges=[df[cols].describe()['min'],
          df[cols].describe()['25%'],
          df[cols].describe()['50%'],
          df[cols].describe()['75%'],
          df[cols].describe()['max']]
           
    df[cols]=pd.cut(df[cols],edges,labels=labels)
    return df

labels=['not_popular','below_avg','average','polpular']

popularity(df,'Vote_Average',labels)
# Out:
#       Release_Date                                 Title  Popularity  \
# 0             2021               Spider-Man: No Way Home    5083.954
# 1             2022                            The Batman    3827.658
# 2             2022                               No Exit    2618.087
# 3             2021                               Encanto    2402.201
# 4             2021                        The King's Man    1895.511
# ...            ...                                   ...         ...
# 9822          1973                              Badlands      13.357
# 9823          2020                      Violent Delights      13.356
# 9824          2016                          The Offering      13.355
# 9825          2021  The United States vs. Billie Holiday      13.354
# 9826          1984                               Threads      13.354
#
#       Vote_Count Vote_Average                               Genre
# 0           8940     polpular  Action, Adventure, Science Fiction
# ...

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 1          2022               The Batman    3827.658        1151     polpular
# 2          2022                  No Exit    2618.087         122    below_avg
# 3          2021                  Encanto    2402.201        5076     polpular
# 4          2021           The King's Man    1895.511        1793      average
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# not_popular    2467
# polpular       2450
# average        2412
# below_avg      2398
# Name: count, dtype: int64

# %% [markdown]
# # One GENRE per row

# %%
df['Genre']= df['Genre'].str.split(', ')

df=df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 1          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 2          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 3          2022               The Batman    3827.658        1151     polpular
# 4          2022               The Batman    3827.658        1151     polpular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
df['Genre']=df['Genre'].astype('category')

# %%
df['Genre'].describe()
# Out:
# count     25793
# unique       19
# top       Drama
# freq       3744
# Name: Genre, dtype: object

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # 1) What is the most frequent Genre of movie released on netflix?

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Drama              3744
# Comedy             3031
# Action             2686
# Thriller           2488
# Adventure          1853
# Romance            1476
# Horror             1470
# Animation          1439
# Family             1414
# Fantasy            1308
# Science Fiction    1273
# Crime              1242
# Mystery             773
# History             427
# War                 308
# Music               295
# Documentary         215
# TV Movie            214
# Western             137
# Name: count, dtype: int64

# %%
genre_counts = df['Genre'].value_counts().reset_index()
genre_counts.columns = ['Genre', 'Count']
genre_counts
# Out:
#               Genre  Count
# 0             Drama   3744
# 1            Comedy   3031
# 2            Action   2686
# 3          Thriller   2488
# 4         Adventure   1853
# 5           Romance   1476
# 6            Horror   1470
# 7         Animation   1439
# 8            Family   1414
# 9           Fantasy   1308
# 10  Science Fiction   1273
# 11            Crime   1242
# 12          Mystery    773
# 13          History    427
# 14              War    308
# 15            Music    295
# 16      Documentary    215
# 17         TV Movie    214
# 18          Western    137

# %%
plt.style.use('ggplot')

# %%
sns.barplot(y='Genre', x='Count', data=genre_counts,
            order = df['Genre'].value_counts().index,
            color='lightcoral',
           edgecolor='Black')
plt.title('Genre column Distribution')
plt.tight_layout()

# %% [markdown]
# # 2) Which has highest votes in vote average column?

# %%
votes=df['Vote_Average'].value_counts().reset_index()
votes.columns=['Vote_Average','Votes']
votes
# Out:
#   Vote_Average  Votes
# 0      average   6613
# 1     polpular   6520
# 2    below_avg   6348
# 3  not_popular   6071

# %%
sns.barplot(y='Vote_Average' ,x='Votes', data=votes,
           order=df['Vote_Average'].value_counts().index,
           color='skyblue',
           edgecolor='Black')

plt.xlabel('VOTES')
plt.ylabel('VOTE AVERAGE')
plt.title('Votes Distribution')
# Out:
# Text(0.5, 1.0, 'Votes Distribution')

# %% [markdown]
# # 3) Which movie has got the highest popularity ? What is its genre?

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 1          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 2          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 3          2022               The Batman    3827.658        1151     polpular
# 4          2022               The Batman    3827.658        1151     polpular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
df.sort_values(['Popularity'], ascending=False)
# Out:
#        Release_Date                                 Title  Popularity  \
# 0              2021               Spider-Man: No Way Home    5083.954
# 2              2021               Spider-Man: No Way Home    5083.954
# 1              2021               Spider-Man: No Way Home    5083.954
# 3              2022                            The Batman    3827.658
# 5              2022                            The Batman    3827.658
# ...             ...                                   ...         ...
# 25788          2021  The United States vs. Billie Holiday      13.354
# 25789          2021  The United States vs. Billie Holiday      13.354
# 25790          1984                               Threads      13.354
# 25791          1984                               Threads      13.354
# 25792          1984                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre
# 0            8940     polpular           Action
# ...

# %%
df[df['Popularity']== df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 1          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 2          2021  Spider-Man: No Way Home    5083.954        8940     polpular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction

# %% [markdown]
# # 4) Which movie has got the Lowest popularity ? What is its genre?

# %%
df[df['Popularity']== df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25787          2021  The United States vs. Billie Holiday      13.354
# 25788          2021  The United States vs. Billie Holiday      13.354
# 25789          2021  The United States vs. Billie Holiday      13.354
# 25790          1984                               Threads      13.354
# 25791          1984                               Threads      13.354
# 25792          1984                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre
# 25787         152      average            Music
# 25788         152      average            Drama
# 25789         152      average          History
# 25790         186     polpular              War
# 25791         186     polpular            Drama
# 25792         186     polpular  Science Fiction

# %% [markdown]
# # 5) Which year has the most movies filmed?

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 1          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 2          2021  Spider-Man: No Way Home    5083.954        8940     polpular
# 3          2022               The Batman    3827.658        1151     polpular
# 4          2022               The Batman    3827.658        1151     polpular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
df['Release_Date'].hist(edgecolor='Black')
plt.xlabel('YEARS')
plt.ylabel('COUNT')
plt.title('Released movie year distribution')
# Out:
# Text(0.5, 1.0, 'Released movie year distribution')
